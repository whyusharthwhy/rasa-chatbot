# %%
from rasa_nlu.training_data import load_data
from rasa_nlu.model import Trainer
from rasa_nlu import config
from rasa_nlu.model import Interpreter
def train_horoscopebot(data_json, config_file, model_dir):
    training_data = load_data(data_json)
    trainer = Trainer(config.load(config_file))
    trainer.train(training_data)
    model_directory = trainer.persist(model_dir, fixed_model_name ='horoscopebot')
def predict_intent(text):
    interpreter = Interpreter.load('./models/nlu/default/horoscopebot')
    print(interpreter.parse(text))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7012\2752648414.py in <module>
# ----> 1 from rasa_nlu.training_data import load_data
#       2 from rasa_nlu.model import Trainer
#       3 from rasa_nlu import config
#       4 from rasa_nlu.model import Interpreter
#       5 def train_horoscopebot(data_json, config_file, model_dir):
#
# ModuleNotFoundError: No module named 'rasa_nlu'

# %%
# !pip install rasa
# Out:
# Requirement already satisfied: rasa in d:\projects\chatbot-rasa\env\lib\site-packages (3.4.2)
# Requirement already satisfied: sanic-jwt<2.0.0,>=1.6.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (1.8.0)
# Requirement already satisfied: google-auth<3 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (2.16.0)
# Requirement already satisfied: pydot<1.5,>=1.4 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (1.4.2)
# Requirement already satisfied: python-engineio!=5.0.0,<6,>=4 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (4.3.4)
# Requirement already satisfied: twilio<7.15,>=6.26 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (7.14.2)
# Requirement already satisfied: mattermostwrapper<2.3,>=2.2 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (2.2)
# Requirement already satisfied: tqdm<5.0,>=4.31 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (4.64.1)
# Requirement already satisfied: colorhash<1.3.0,>=1.0.2 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (1.2.1)
# Requirement already satisfied: jsonpickle<2.3,>=1.3 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (2.2.0)
# Requirement already satisfied: pydantic<1.10.3 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (1.10.2)
# Requirement already satisfied: tarsafe<0.0.4,>=0.0.3 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (0.0.3)
# Requirement already satisfied: colorclass<2.3,>=2.2 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (2.2.2)
# Requirement already satisfied: cloudpickle<2.3,>=1.2 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (2.2.1)
# Requirement already satisfied: randomname<0.2.0,>=0.1.5 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (0.1.5)
# Requirement already satisfied: networkx<2.7,>=2.4 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (2.6.3)
# Requirement already satisfied: requests<3.0,>=2.23 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (2.28.2)
# Requirement already satisfied: ujson<6.0,>=1.35 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (5.7.0)
# Requirement already satisfied: python-dateutil<2.9,>=2.8 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (2.8.2)
# Requirement already satisfied: aiohttp!=3.7.4.post0,<3.9,>=3.6 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (3.8.3)
# Requirement already satisfied: matplotlib<3.6,>=3.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (3.5.3)
# Requirement already satisfied: ruamel.yaml<0.18.0,>=0.16.5 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (0.17.21)
# Requirement already satisfied: SQLAlchemy<1.5.0,>=1.4.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (1.4.46)
# Requirement already satisfied: prompt-toolkit<3.0.29,>=3.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (3.0.28)
# Requirement already satisfied: fbmessenger<6.1.0,>=6.0.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (6.0.0)
# Requirement already satisfied: PyJWT[crypto]<3.0.0,>=2.0.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (2.6.0)
# Requirement already satisfied: confluent-kafka<2.0.0,>=1.9.2 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (1.9.2)
# Requirement already satisfied: tensorflow<2.9.0,>=2.8.4 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (2.8.4)
# Requirement already satisfied: sentry-sdk<1.12.0,>=0.17.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (1.11.1)
# Requirement already satisfied: pymongo[srv,tls]<3.11,>=3.8 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (3.10.1)
# Requirement already satisfied: aiogram<2.24 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (2.23.1)
# Requirement already satisfied: psycopg2-binary<2.10.0,>=2.8.2 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (2.9.5)
# Requirement already satisfied: boto3<2.0,>=1.12 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (1.26.63)
# Requirement already satisfied: absl-py<1.4,>=0.9 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (1.3.0)
# Requirement already satisfied: packaging<21.0,>=20.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (20.9)
# Requirement already satisfied: rocketchat_API<1.29.0,>=0.6.31 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (1.28.1)
# Requirement already satisfied: tensorflow-addons<0.18.0,>=0.17.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (0.17.1)
# Requirement already satisfied: aio-pika<9.0.0,>=6.7.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (8.3.0)
# Requirement already satisfied: setuptools>=41.0.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (66.1.1)
# Requirement already satisfied: sklearn-crfsuite<0.4,>=0.3 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (0.3.6)
# Requirement already satisfied: numpy<1.24.0,>=1.19.2 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (1.23.5)
# Requirement already satisfied: typing-utils<0.2.0,>=0.1.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (0.1.0)
# Requirement already satisfied: questionary<1.11.0,>=1.5.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (1.10.0)
# Requirement already satisfied: terminaltables<3.2.0,>=3.1.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (3.1.10)
# Requirement already satisfied: tensorflow_hub<0.13.0,>=0.12.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (0.12.0)
# Requirement already satisfied: webexteamssdk<1.7.0,>=1.1.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (1.6.1)
# Requirement already satisfied: colorama<0.5.0,>=0.4.4 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (0.4.6)
# Requirement already satisfied: sanic<21.13,>=21.12 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (21.12.2)
# Requirement already satisfied: apscheduler<3.10,>=3.6 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (3.9.1.post1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (4.4.0)
# Requirement already satisfied: redis<5.0,>=3.4 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (4.4.2)
# Requirement already satisfied: regex<2022.11,>=2020.6 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (2022.10.31)
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (1.0.0)
# Requirement already satisfied: dask==2022.10.2 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (2022.10.2)
# Requirement already satisfied: coloredlogs<16,>=10 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (10.0)
# Requirement already satisfied: joblib<1.3.0,>=0.15.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (1.2.0)
# Requirement already satisfied: pykwalify<1.9,>=1.7 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (1.8.0)
# Requirement already satisfied: scikit-learn<1.2,>=0.22 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (1.1.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (3.19.6)
# Requirement already satisfied: rasa-sdk<3.5.0,>=3.4.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (3.4.0)
# Requirement already satisfied: pytz<2023.0,>=2019.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (2022.7.1)
# Requirement already satisfied: python-socketio<6,>=4.4 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (5.7.2)
# Requirement already satisfied: scipy<1.9.0,>=1.4.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (1.8.1)
# Requirement already satisfied: CacheControl<0.13.0,>=0.12.9 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (0.12.11)
# Requirement already satisfied: sanic-routing<0.8.0,>=0.7.2 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (0.7.2)
# Requirement already satisfied: attrs<22.2,>=19.3 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (22.1.0)
# Requirement already satisfied: sanic-cors<2.1.0,>=2.0.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (2.0.1)
# Requirement already satisfied: slack-sdk<4.0.0,>=3.19.2 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (3.19.5)
# Requirement already satisfied: jsonschema<4.17,>=3.2 in d:\projects\chatbot-rasa\env\lib\site-packages (from rasa) (4.16.0)
# Requirement already satisfied: toolz>=0.8.2 in d:\projects\chatbot-rasa\env\lib\site-packages (from dask==2022.10.2->rasa) (0.12.0)
# Requirement already satisfied: click>=7.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from dask==2022.10.2->rasa) (8.1.3)
# Requirement already satisfied: fsspec>=0.6.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from dask==2022.10.2->rasa) (2023.1.0)
# Requirement already satisfied: partd>=0.3.10 in d:\projects\chatbot-rasa\env\lib\site-packages (from dask==2022.10.2->rasa) (1.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from dask==2022.10.2->rasa) (6.0)
# Requirement already satisfied: aiormq~=6.6.3 in d:\projects\chatbot-rasa\env\lib\site-packages (from aio-pika<9.0.0,>=6.7.1->rasa) (6.6.4)
# Requirement already satisfied: yarl in d:\projects\chatbot-rasa\env\lib\site-packages (from aio-pika<9.0.0,>=6.7.1->rasa) (1.8.2)
# Requirement already satisfied: Babel<2.10.0,>=2.9.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from aiogram<2.24->rasa) (2.9.1)
# Requirement already satisfied: certifi>=2021.10.8 in d:\projects\chatbot-rasa\env\lib\site-packages (from aiogram<2.24->rasa) (2022.12.7)
# Requirement already satisfied: magic-filter>=1.0.9 in d:\projects\chatbot-rasa\env\lib\site-packages (from aiogram<2.24->rasa) (1.0.9)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\projects\chatbot-rasa\env\lib\site-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in d:\projects\chatbot-rasa\env\lib\site-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\projects\chatbot-rasa\env\lib\site-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa) (5.2.0)
# Requirement already satisfied: six>=1.4.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from apscheduler<3.10,>=3.6->rasa) (1.16.0)
# Requirement already satisfied: tzlocal!=3.*,>=2.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from apscheduler<3.10,>=3.6->rasa) (4.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from boto3<2.0,>=1.12->rasa) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from boto3<2.0,>=1.12->rasa) (0.6.0)
# Requirement already satisfied: botocore<1.30.0,>=1.29.63 in d:\projects\chatbot-rasa\env\lib\site-packages (from boto3<2.0,>=1.12->rasa) (1.29.63)
# Requirement already satisfied: msgpack>=0.5.2 in d:\projects\chatbot-rasa\env\lib\site-packages (from CacheControl<0.13.0,>=0.12.9->rasa) (1.0.4)
# Requirement already satisfied: humanfriendly>=4.7 in d:\projects\chatbot-rasa\env\lib\site-packages (from coloredlogs<16,>=10->rasa) (10.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\projects\chatbot-rasa\env\lib\site-packages (from google-auth<3->rasa) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from google-auth<3->rasa) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from google-auth<3->rasa) (5.3.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from jsonschema<4.17,>=3.2->rasa) (0.19.3)
# Requirement already satisfied: cycler>=0.10 in d:\projects\chatbot-rasa\env\lib\site-packages (from matplotlib<3.6,>=3.1->rasa) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from matplotlib<3.6,>=3.1->rasa) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from matplotlib<3.6,>=3.1->rasa) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from matplotlib<3.6,>=3.1->rasa) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from matplotlib<3.6,>=3.1->rasa) (1.4.4)
# Requirement already satisfied: wcwidth in d:\projects\chatbot-rasa\env\lib\site-packages (from prompt-toolkit<3.0.29,>=3.0->rasa) (0.2.6)
# Requirement already satisfied: cryptography>=3.4.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from PyJWT[crypto]<3.0.0,>=2.0.0->rasa) (39.0.0)
# Requirement already satisfied: docopt>=0.6.2 in d:\projects\chatbot-rasa\env\lib\site-packages (from pykwalify<1.9,>=1.7->rasa) (0.6.2)
# Requirement already satisfied: dnspython<2.0.0,>=1.16.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from pymongo[srv,tls]<3.11,>=3.8->rasa) (1.16.0)
# Requirement already satisfied: bidict>=0.21.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from python-socketio<6,>=4.4->rasa) (0.22.1)
# Requirement already satisfied: fire in d:\projects\chatbot-rasa\env\lib\site-packages (from randomname<0.2.0,>=0.1.5->rasa) (0.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from requests<3.0,>=2.23->rasa) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in d:\projects\chatbot-rasa\env\lib\site-packages (from requests<3.0,>=2.23->rasa) (3.4)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in d:\projects\chatbot-rasa\env\lib\site-packages (from ruamel.yaml<0.18.0,>=0.16.5->rasa) (0.2.7)
# Requirement already satisfied: websockets>=10.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from sanic<21.13,>=21.12->rasa) (10.4)
# Requirement already satisfied: aiofiles>=0.6.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from sanic<21.13,>=21.12->rasa) (22.1.0)
# Requirement already satisfied: httptools>=0.0.10 in d:\projects\chatbot-rasa\env\lib\site-packages (from sanic<21.13,>=21.12->rasa) (0.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from scikit-learn<1.2,>=0.22->rasa) (3.1.0)
# Requirement already satisfied: python-crfsuite>=0.8.3 in d:\projects\chatbot-rasa\env\lib\site-packages (from sklearn-crfsuite<0.4,>=0.3->rasa) (0.9.9)
# Requirement already satisfied: tabulate in d:\projects\chatbot-rasa\env\lib\site-packages (from sklearn-crfsuite<0.4,>=0.3->rasa) (0.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in d:\projects\chatbot-rasa\env\lib\site-packages (from SQLAlchemy<1.5.0,>=1.4.0->rasa) (2.0.1)
# Requirement already satisfied: libclang>=9.0.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorflow<2.9.0,>=2.8.4->rasa) (15.0.6.1)
# Requirement already satisfied: h5py>=2.9.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorflow<2.9.0,>=2.8.4->rasa) (3.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorflow<2.9.0,>=2.8.4->rasa) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorflow<2.9.0,>=2.8.4->rasa) (23.1.21)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorflow<2.9.0,>=2.8.4->rasa) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorflow<2.9.0,>=2.8.4->rasa) (0.2.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorflow<2.9.0,>=2.8.4->rasa) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorflow<2.9.0,>=2.8.4->rasa) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorflow<2.9.0,>=2.8.4->rasa) (2.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorflow<2.9.0,>=2.8.4->rasa) (0.30.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorflow<2.9.0,>=2.8.4->rasa) (2.8.0)
# Requirement already satisfied: gast>=0.2.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorflow<2.9.0,>=2.8.4->rasa) (0.5.3)
# Requirement already satisfied: wrapt>=1.11.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorflow<2.9.0,>=2.8.4->rasa) (1.14.1)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorflow<2.9.0,>=2.8.4->rasa) (2.8.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorflow<2.9.0,>=2.8.4->rasa) (1.51.1)
# Requirement already satisfied: typeguard>=2.7 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorflow-addons<0.18.0,>=0.17.0->rasa) (2.13.3)
# Requirement already satisfied: future in d:\projects\chatbot-rasa\env\lib\site-packages (from webexteamssdk<1.7.0,>=1.1.1->rasa) (0.17.1)
# Requirement already satisfied: requests-toolbelt in d:\projects\chatbot-rasa\env\lib\site-packages (from webexteamssdk<1.7.0,>=1.1.1->rasa) (0.10.1)
# Requirement already satisfied: pamqp==3.2.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from aiormq~=6.6.3->aio-pika<9.0.0,>=6.7.1->rasa) (3.2.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.9.0,>=2.8.4->rasa) (0.38.4)
# Requirement already satisfied: cffi>=1.12 in d:\projects\chatbot-rasa\env\lib\site-packages (from cryptography>=3.4.0->PyJWT[crypto]<3.0.0,>=2.0.0->rasa) (1.15.1)
# Requirement already satisfied: pyreadline3 in d:\projects\chatbot-rasa\env\lib\site-packages (from humanfriendly>=4.7->coloredlogs<16,>=10->rasa) (3.4.1)
# Requirement already satisfied: locket in d:\projects\chatbot-rasa\env\lib\site-packages (from partd>=0.3.10->dask==2022.10.2->rasa) (1.0.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\projects\chatbot-rasa\env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3->rasa) (0.4.8)
# Requirement already satisfied: markdown>=2.6.8 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in d:\projects\chatbot-rasa\env\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa) (2.2.2)
# Requirement already satisfied: tzdata in d:\projects\chatbot-rasa\env\lib\site-packages (from tzlocal!=3.*,>=2.0->apscheduler<3.10,>=3.6->rasa) (2022.7)
# Requirement already satisfied: pytz-deprecation-shim in d:\projects\chatbot-rasa\env\lib\site-packages (from tzlocal!=3.*,>=2.0->apscheduler<3.10,>=3.6->rasa) (0.1.0.post0)
# Requirement already satisfied: pycparser in d:\projects\chatbot-rasa\env\lib\site-packages (from cffi>=1.12->cryptography>=3.4.0->PyJWT[crypto]<3.0.0,>=2.0.0->rasa) (2.21)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\projects\chatbot-rasa\env\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa) (6.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\projects\chatbot-rasa\env\lib\site-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in d:\projects\chatbot-rasa\env\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa) (3.12.0)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\projects\chatbot-rasa\env\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa) (3.2.2)
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
